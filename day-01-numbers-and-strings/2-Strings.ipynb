# %%
"Hello World!"
# Out:
# 'Hello World!'

# %%
print("Hello Python!") #tek tırnak da olur
# Out:
# Hello Python!

# %%
name = "Ömer"

# %%
type(name)
# Out:
# str

# %%
print(name)
# Out:
# Ömer

# %%
name = "ömer ocak"

# %%
name.capitalize() #ilk harfi büyük yapar 
# () çalıştır anlamına gelir
# Out:
# 'Ömer ocak'

# %%
help(name.count) # help sayesinde ne olduğu hakkında bilgi alabiliriz
# Out:
# Help on built-in function count:
#
# count(sub[, start[, end]], /) method of builtins.str instance
#     Return the number of non-overlapping occurrences of substring sub in string S[start:end].
#
#     Optional arguments start and end are interpreted as in slice notation.

# %%
name.count("a") # içinde kaç tane "a" var gibi sayıları verir
# Out:
# 1

# %%
name.upper() # tüm harfleri büyük yapar
# Out:
# 'ÖMER OCAK'

# %%
name
# Out:
# 'ömer ocak'

# %%
x = 10 
y = 20

# %%
x + y
# Out:
# 30

# %%
z = x + y

# %%
z
# Out:
# 30

# %%
Name = name.upper()

# %%
Name
# Out:
# 'ÖMER OCAK'

# %%
name
# Out:
# 'ömer ocak'

# %%
len # length -> uzunluk karakter syısını verir
# Out:
# <function len(obj, /)>

# %%
len(name)
# Out:
# 9

# %%
print("Ömer \nOcak")  #\n -> new line
# Out:
# Ömer
# Ocak
