# %%
#unique elements, unordered (#benzersiz öğeler, sıralanmamış)

# %%
myList = [10,20,50,40,50,10,70,20,90]

# %%
len(myList)
# Out:
# 9

# %%
myList
# Out:
# [10, 20, 50, 40, 50, 10, 70, 20, 90]

# %%
# set -> sadece benzersiz öğeleri alır 
# set içinde her elemandan sadece bir tane olabilir

# %%
mySet = set(myList)

# %%
mySet
# Out:
# {10, 20, 40, 50, 70, 90}

# %%
newSet = {10, 25, 29, 45, 25, 29, 45, 25, 29, 45}

# %%
newSet
# Out:
# {10, 25, 29, 45}

# %%
newSet.add(10)

# %%
newSet
# Out:
# {10, 25, 29, 45}

# %%
newSet.add(50)

# %%
newSet
# Out:
# {10, 25, 29, 45, 50}

# %%
# ** newSet[0] ** indeks mantığı yok

# %%
newSet2 = {1,2,3,4,5,29,45}

# %%
newSet.union(newSet2) # birleştirme
# Out:
# {1, 2, 3, 4, 5, 10, 25, 29, 45, 50}

# %%
newSet.intersection(newSet2) # kesişimlerini bulma
# Out:
# {29, 45}

# %%
####

# %%
emptyList = [] # boş liste -> emptyList = list()

# %%
emptyList.append(21)
emptyList.append(34)
emptyList.append(35)

# %%
emptyList
# Out:
# [21, 34, 35]

# %%
# boş sözlük ve set ???

# %%
emptySet = {} 
emptyDictionary = {} # boş sözlük -> emptyDictionary = dict()

# %%
type(emptySet)
# Out:
# dict

# %%
type(emptyDictionary)
# Out:
# dict

# %%
emptySet = set() # boş set

# %%
type(emptySet)
# Out:
# set

# %%
emptySet.add(20)
emptySet.add(20)
emptySet.add(40)
emptySet.add(20)
emptySet.add(80)

# %%
emptySet
# Out:
# {20, 40, 80}
