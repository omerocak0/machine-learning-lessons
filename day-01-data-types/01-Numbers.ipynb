# %%
# yorum satırı

# %% [markdown]
# Veri Tipleri

# %%
type(10)
# Out:
# int

# %%
type(25*4)
# Out:
# int

# %%
type(25/4)
# Out:
# float

# %%
x = -100
type(x)
# Out:
# int

# %%
ad = "Omer"
type(ad)
# Out:
# str

# %%
# camelCase
# snake_case

# %%
type(50/5)
# Out:
# float

# %%
50/5
# Out:
# 10.0

# %%
2 ** 5 # üs(kuvvet) alma
# Out:
# 32

# %%
10 % 3 #kalan bulma
# Out:
# 1
