# %%
myString = "machine learning"

# %%
myString.split()
# Out:
# ['machine', 'learning']

# %%
type(myString.split())
# Out:
# list

# %%
# myString[0] = "a"  -> immutable | immutability (değiştirilemez)

# %%
myList = [10,30,50]

# %%
x = 10
y = 30
z = 50

# %%
myList = [x,y,z]

# %%
type(myList)
# Out:
# list

# %%
type(myList[0])
# Out:
# int

# %%
myList[1]
# Out:
# 30

# %%
myList[1] = 35 # -> mutable | mutability (değiştirilebilir)

# %%
myList[1]
# Out:
# 35

# %%
myList
# Out:
# [10, 35, 50]

# %%
len(myList)
# Out:
# 3

# %%
myList[len(myList) - 1] # listenin son elemanı
# Out:
# 50

# %%
myList[-1]
# Out:
# 50

# %%
myList[-2]
# Out:
# 35

# %%
myList.append(70) # yeni eleman ekleme

# %%
myList
# Out:
# [10, 35, 50, 70]

# %%
myList.append(0)

# %%
myList.count(10) # içinde istenen eleman sayısını verir
# Out:
# 1

# %%
myList.index(70) # kaçıncı index te olduğunu verir
# Out:
# 3

# %%
myList.insert(3,75)  # istenilen index e istenen değeri ekler

# %%
myList
# Out:
# [10, 35, 50, 75, 70, 0]

# %%
myList[3]
# Out:
# 75

# %%
myList.pop() # son elemanı çıkarır
# Out:
# 0

# %%
myList
# Out:
# [10, 35, 50, 75, 70]

# %%
myList.remove(50) # istenilen değeri listeden çıkarır

# %%
myList
# Out:
# [10, 35, 75, 70]

# %%
myList.reverse() # listeyi tersine çevirir

# %%
myList
# Out:
# [70, 75, 35, 10]

# %%
myList.sort() # küçükten büyüğe sıralar (sadece sayılarda değil stringlerde alfabetik olarak sıralar)

# %%
myList
# Out:
# [10, 35, 70, 75]

# %% [markdown]
# Dışarıdan Değer Alma

# %%
x = input("enter x: ")
# Out:
# enter x:  21

# %%
x
# Out:
# '21'

# %%
type(x)
# Out:
# str

# %%
y = input("enter y: ")
# Out:
# enter y:  35

# %%
y
# Out:
# '35'

# %%
z = input("enter z: ")
# Out:
# enter z:  51

# %%
inputList = []

# %%
type(inputList)
# Out:
# list

# %%
len(inputList)
# Out:
# 0

# %%
inputList.append(x)
inputList.append(y)
inputList.append(z)

# %%
inputList
# Out:
# ['21', '35', '51']

# %%
inputList[1]
# Out:
# '35'

# %%
inputList[1] * 2
# Out:
# '3535'

# %%
type(inputList[1])
# Out:
# str

# %%
mixedList = ["Ömer", "Ocak", 21 , 1.80]

# %%
type(mixedList)
# Out:
# list

# %%
list1 = [10,20,30]
list2 = [40, 50, 60]

# %%
list = list1 + list2

# %%
list
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
list1 * 2 # çarpma durumunda aynı listeden kaçla çarpılmak istense o kadar yazdırılır
# Out:
# [10, 20, 30, 10, 20, 30]

# %%
list1 + [21] # yeni elenan ekleme
# Out:
# [10, 20, 30, 21]

# %%
mixedList
# Out:
# ['Ömer', 'Ocak', 21, 1.8]

# %%
type(mixedList[2])
# Out:
# int

# %%
type(mixedList[0])
# Out:
# str

# %%
type(mixedList[3])
# Out:
# float

# %%
#nestedList -> iç içe geçmiş listeler

# %%
myNestedList = ["Ömer", "Ocak", 21, 1.80, ["Makine Öğrenmesi", "Algoritma Analizi"]]

# %%
myNestedList[0]
# Out:
# 'Ömer'

# %%
myNestedList[4]
# Out:
# ['Makine Öğrenmesi', 'Algoritma Analizi']

# %%
myNestedList[4][0]
# Out:
# 'Makine Öğrenmesi'

# %%
myNestedList[4][1]
# Out:
# 'Algoritma Analizi'

# %%
type(myNestedList[4])
# Out:
# list

# %%
type(myNestedList[4][0])
# Out:
# str

# %%
type(myNestedList[4][1])
# Out:
# str
