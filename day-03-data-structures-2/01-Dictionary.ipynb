# %%
# key - value pairing

# %%
fruit_list = ["banana", "orange"]

# %%
calorie_list = [100, 120]

# %%
# kullanılması mantıklı değil

# %%
# dictionary {key: value, ...}

# %%
fruit_calorie = {"banana": 100, "orange": 120}

# %%
type(fruit_calorie)
# Out:
# dict

# %%
# ** fruit_calorie[0] ** listeler gibi burda indeks mantığı yok direkt key yazılır

# %%
fruit_calorie["banana"]
# Out:
# 100

# %%
fruit_calorie["orange"]
# Out:
# 120

# %%
fruit_calorie.keys() # anahtarları verir
# Out:
# dict_keys(['banana', 'orange'])

# %%
fruit_calorie.values() # değerleri verir
# Out:
# dict_values([100, 120])

# %%
type(fruit_calorie.values())
# Out:
# dict_values

# %%
list(fruit_calorie.values()) # değerleri listeye çevirdi
# Out:
# [100, 120]

# %%
fruit_calorie["banana"] = 175 # eleman güncelleme

# %%
fruit_calorie
# Out:
# {'banana': 175, 'orange': 120}

# %%
fruit_calorie["kiwi"] = 250 # yeni eleman ekleme

# %%
fruit_calorie
# Out:
# {'banana': 175, 'orange': 120, 'kiwi': 250}

# %%
fruit_calorie.get
# Out:
# <function dict.get(key, default=None, /)>

# %%
fruit_calorie.get("apple", 0) # yoksa sıfır ver
# Out:
# 0

# %%
fruit_calorie.get("orange", 0) # varsa değerini getir
# Out:
# 120

# %%
days_week = {1:"Pazartesi", 
             2:"Salı",
             3:"Çarşamba",
             4:"Perşembe",
             5:"Cuma",
             6:"Cumartesi",
             7:"Pazar" }

# %%
type(days_week)
# Out:
# dict

# %%
days_week[3]
# Out:
# 'Çarşamba'

# %%
days_week[3][5] # 3 numaralı keyin 5. indeksteki harfini al Çarşamba
# Out:
# 'm'

# %%
dictionary = {"k1":10,
              "k2":[10,20,30,40,50],
              "k3":"Ömer",
              "k4":{"a":100, "b":200}
             }

# %%
#200
dictionary["k4"]["b"]
# Out:
# 200

# %%
#40
dictionary["k2"][3]
# Out:
# 40
