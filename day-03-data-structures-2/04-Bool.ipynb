# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
myBoolean = True

# %%
type(myBoolean)
# Out:
# bool

# %%
5 > 3
# Out:
# True

# %%
3 > 5
# Out:
# False

# %%
age = input("Yaşınız: ")
# Out:
# Yaşınız:  18

# %%
age
# Out:
# '18'

# %%
int(age)
# Out:
# 18

# %%
int(age) >= 18
# Out:
# True
