# %%
myTuple = (10, "a", "b", 3.14)

# %%
type(myTuple)
# Out:
# tuple

# %%
# myTuple[0] = 100 
# elemanlar değiştirilemez veya yeni eleman eklenemez

# %%
myTuple.index("a")
# Out:
# 1

# %%
myTuple.count("a")
# Out:
# 1
