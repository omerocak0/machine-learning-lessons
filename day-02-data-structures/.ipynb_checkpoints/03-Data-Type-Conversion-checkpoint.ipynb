# %% [markdown]
# int -> str

# %%
integer = 70

# %%
type(integer)
# Out:
# int

# %%
str(integer)
# Out:
# '70'

# %%
type(str(integer))
# Out:
# str

# %% [markdown]
# str -> int & float

# %%
string = "40"

# %%
type(string)
# Out:
# str

# %%
int(string)
# Out:
# 40

# %%
type(int(string))
# Out:
# int

# %%
float(string)
# Out:
# 40.0
